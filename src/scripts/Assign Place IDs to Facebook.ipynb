# %%
# Install Supabase
# !pip3 install supabase

# Init Supabase and read from .env
import os
from supabase import create_client, Client

url: str = os.environ.get("VITE_SUPABASE_URL")
key: str = os.environ.get("VITE_SUPABASE_ANON_KEY")
supabase: Client = create_client(url, key)
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: supabase in /usr/local/lib/python3.9/site-packages (0.5.6)
# Requirement already satisfied: postgrest-py<0.11.0,>=0.10.2 in /usr/local/lib/python3.9/site-packages (from supabase) (0.10.2)
# Requirement already satisfied: realtime<0.0.5,>=0.0.4 in /usr/local/lib/python3.9/site-packages (from supabase) (0.0.4)
# Requirement already satisfied: gotrue<0.6.0,>=0.5.0 in /usr/local/lib/python3.9/site-packages (from supabase) (0.5.0)
# Requirement already satisfied: storage3<0.4.0,>=0.3.1 in /usr/local/lib/python3.9/site-packages (from supabase) (0.3.1)
# Requirement already satisfied: httpx<0.22.0,>=0.21.3 in /usr/local/lib/python3.9/site-packages (from supabase) (0.21.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /usr/local/lib/python3.9/site-packages (from gotrue<0.6.0,>=0.5.0->supabase) (1.9.0)
# Requirement already satisfied: httpcore<0.15.0,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (0.14.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (1.5.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (2.0.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (2021.10.8)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /usr/local/lib/python3.9/site-packages (from postgrest-py<0.11.0,>=0.10.2->supabase) (2.1.0)
# Requirement already satisfied: websockets<10.0,>=9.1 in /usr/local/lib/python3.9/site-packages (from realtime<0.0.5,>=0.0.4->supabase) (9.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /usr/local/lib/python3.9/site-packages (from realtime<0.0.5,>=0.0.4->supabase) (2.8.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /usr/local/lib/python3.9/site-packages (from storage3<0.4.0,>=0.3.1->supabase) (4.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from deprecation<3.0.0,>=2.1.0->postgrest-py<0.11.0,>=0.10.2->supabase) (21.3)
# Requirement already satisfied: anyio==3.* in /usr/local/lib/python3.9/site-packages (from httpcore<0.15.0,>=0.14.0->httpx<0.22.0,>=0.21.3->supabase) (3.4.0)
# Requirement already satisfied: h11<0.13,>=0.11 in /usr/local/lib/python3.9/site-packages (from httpcore<0.15.0,>=0.14.0->httpx<0.22.0,>=0.21.3->supabase) (0.12.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.9/site-packages (from anyio==3.*->httpcore<0.15.0,>=0.14.0->httpx<0.22.0,>=0.21.3->supabase) (3.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<0.0.5,>=0.0.4->supabase) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging->deprecation<3.0.0,>=2.1.0->postgrest-py<0.11.0,>=0.10.2->supabase) (3.0.8)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: There was an error checking the latest version of pip.

# %%
facebook = supabase.table('facebook').select('*').execute()
facebook.data

# Filter out the places that have already been assigned a place ID
# Out:
# [{'id': 20132,
#   'upi': 14310231,
#   'netid': 'yj74',
#   'email': 'yichen.jia@yale.edu',
#   'mailbox': 'yichen.jia@bulldogs.yale.edu',
#   'first_name': 'Yichen',
#   'last_name': 'Jia',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'ITS',
#   'organization': 'Information Technology Services',
#   'title': 'Commencement 2021 Walker',
#   'address': None,
#   'unit_class': 'ITSHMU',
#   'unit_code': 'CC0184',
#   'unit': 'Health Med & University Partners',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 20123,
#   'upi': 17647598,
#   'netid': 'hj329',
#   'email': 'hao.jiang@yale.edu',
#   'mailbox': 'hj329@connect.yale.edu',
#   'first_name': 'Hao',
#   'last_name': 'Jiang',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'FAS',
#   'organization': 'Other FAS and Academic Departments',
#   'title': 'Research Affiliates',
#   'address': None,
#   'unit_class': 'FASEAS',
#   'unit_code': 'CC0511',
#   'unit': 'EE Faculty',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24646255,
#   'netid': 'jdm269',
#   'email': 'johor.mahir@yale.edu',
#   'mailbox': 'jdm269@connect.yale.edu',
#   'first_name': 'Johor',
#   'last_name': 'Mahir',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'ITS',
#   'organization': 'Information Technology Services',
#   'title': 'College Student Intern',
#   'address': '150 Munson Street, New Haven, CT 06511',
#   'unit_class': 'ITSFIN',
#   'unit_code': 'CC0189',
#   'unit': 'Finance & Administration Dir',
#   'postal_address': 'Information Technology Services 4th fl., PO BOX 208207, New Haven, CT 06520-8207',
#   'office_building': 'Science Park Bldg 25',
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': 'Dodiab',
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': 44381,
#   'upi': 24223295,
#   'netid': 'as3837',
#   'email': 'arijit.sehanobish@yale.edu',
#   'mailbox': 'as3837@connect.yale.edu',
#   'first_name': 'Arijit',
#   'last_name': 'Sehanobish',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': 'Postdoctoral Associate',
#   'address': None,
#   'unit_class': 'MEDINT',
#   'unit_code': 'CC1022',
#   'unit': 'Cardiology',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24611456,
#   'netid': 'fsm6',
#   'email': 'forest.mahoney@yale.edu',
#   'mailbox': 'fsm6@connect.yale.edu',
#   'first_name': 'Forest',
#   'last_name': 'Mahoney',
#   'school_code': 'MD',
#   'school': 'School of Medicine',
#   'curriculum': 'Medicine',
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26423,
#   'upi': 24115396,
#   'netid': 'kaf59',
#   'email': 'katie.mahoney@yale.edu',
#   'mailbox': 'kaf59@connect.yale.edu',
#   'first_name': 'Katie',
#   'last_name': 'Mahoney',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_82deed01d03663bda3e3ad4f5c7dcc9d.mp3',
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19411,
#   'upi': 24120853,
#   'netid': 'ci92',
#   'email': 'chinye.ijeli@yale.edu',
#   'mailbox': 'ci92@connect.yale.edu',
#   'first_name': 'Chinye',
#   'last_name': 'Ijeli',
#   'school_code': 'MD',
#   'school': 'School of Medicine',
#   'curriculum': 'Medicine',
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_e293f43d7a741d82ebd0b0af6ecac2f1.mp3',
#   'pronouns': 'she/her',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 20145,
#   'upi': 24576453,
#   'netid': 'pj278',
#   'email': 'peixi.jiang@yale.edu',
#   'mailbox': 'peixi.jiang@bulldogs.yale.edu',
#   'first_name': 'Peixi',
#   'last_name': 'Jiang',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26403,
#   'upi': 24328678,
#   'netid': 'am3572',
#   'email': 'anne.mailey@yale.edu',
#   'mailbox': 'anne.mailey@bulldogs.yale.edu',
#   'first_name': 'Anne',
#   'last_name': 'Mailey',
#   'school_code': 'AT',
#   'school': 'School of Art',
#   'curriculum': 'Painting/Printmaking',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24535211,
#   'netid': 'dm2444',
#   'email': 'daniel.mainye@yale.edu',
#   'mailbox': 'dm2444@connect.yale.edu',
#   'first_name': 'Daniel',
#   'last_name': 'Mainye',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26370,
#   'upi': 24555033,
#   'netid': 'nm756',
#   'email': 'natalie.makableh@yale.edu',
#   'mailbox': 'natalie.makableh@bulldogs.yale.edu',
#   'first_name': 'Natalie',
#   'last_name': 'Makableh',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26439,
#   'upi': 24316999,
#   'netid': 'lm2229',
#   'email': 'laura.makin@yale.edu',
#   'mailbox': 'laura.makin@bulldogs.yale.edu',
#   'first_name': 'Laura',
#   'last_name': 'Makin',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26148,
#   'upi': 24115787,
#   'netid': 'ljm74',
#   'email': 'logan.malach@yale.edu',
#   'mailbox': 'ljm74@connect.yale.edu',
#   'first_name': 'Logan',
#   'last_name': 'Malach',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26310,
#   'upi': 15679139,
#   'netid': 'dm926',
#   'email': 'david.malan@yale.edu',
#   'mailbox': 'dm926@connect.yale.edu',
#   'first_name': 'David',
#   'last_name': 'Malan',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'FAS',
#   'organization': 'Other FAS and Academic Departments',
#   'title': 'Research Affiliates',
#   'address': None,
#   'unit_class': 'FASCPS',
#   'unit_code': 'CC0506',
#   'unit': 'Computer Science',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26144,
#   'upi': 15002165,
#   'netid': 'rm776',
#   'email': 'robert.malcolm@yale.edu',
#   'mailbox': 'rm776@connect.yale.edu',
#   'first_name': 'Robert',
#   'last_name': 'Malcolm',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'SLS',
#   'organization': 'Student Life and Secretary',
#   'title': "Chaplain's Office Affiliate",
#   'address': None,
#   'unit_class': 'SLSCHA',
#   'unit_code': 'CC0368',
#   'unit': 'Office of the Chaplain',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26260,
#   'upi': 24554727,
#   'netid': 'amm377',
#   'email': 'angela.malczyn@yale.edu',
#   'mailbox': 'angela.malczyn@bulldogs.yale.edu',
#   'first_name': 'Angela',
#   'last_name': 'Malczyn',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44440,
#   'upi': 24110058,
#   'netid': 'ehs68',
#   'email': 'elizabeth.searcy@yale.edu',
#   'mailbox': 'elizabeth.searcy@bulldogs.yale.edu',
#   'first_name': 'Elizabeth',
#   'last_name': 'Searcy',
#   'school_code': 'DI',
#   'school': 'Divinity School',
#   'curriculum': 'Ministry, Professional',
#   'organization_code': 'DIV',
#   'organization': 'Divinity School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_27ffbb3176f2a54c17e3ba1ef797e695.mp3',
#   'pronouns': None,
#   'phonetic_name': 'Sir-sea',
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44385,
#   'upi': 17511870,
#   'netid': 'rs2545',
#   'email': 'raghav.sehgal@yale.edu',
#   'mailbox': 'raghav.sehgal@bulldogs.yale.edu',
#   'first_name': 'Raghav',
#   'last_name': 'Sehgal',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Computatnl Bio & Bioinformatcs',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44393,
#   'upi': 24219198,
#   'netid': 'aes255',
#   'email': 'aaron.sents@yale.edu',
#   'mailbox': 'aes255@connect.yale.edu',
#   'first_name': 'Aaron',
#   'last_name': 'Sents',
#   'school_code': 'MD',
#   'school': 'School of Medicine',
#   'curriculum': 'Physician Assistant',
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_bfbcfca3eb55439c7945f93cfc7b844f.mp3',
#   'pronouns': None,
#   'phonetic_name': 'Air-in cents',
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26473,
#   'upi': 24342261,
#   'netid': 'erm57',
#   'email': 'elijah.maletz@yale.edu',
#   'mailbox': 'erm57@connect.yale.edu',
#   'first_name': 'Elijah',
#   'last_name': 'Maletz',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44396,
#   'upi': 15238210,
#   'netid': 'sms323',
#   'email': 'sarah.sebo@yale.edu',
#   'mailbox': 'sarah.sebo@bulldogs.yale.edu',
#   'first_name': 'Sarah',
#   'last_name': 'Sebo',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'ITS',
#   'organization': 'Information Technology Services',
#   'title': 'Commencement 2021 Walker',
#   'address': None,
#   'unit_class': 'ITSHMU',
#   'unit_code': 'CC0184',
#   'unit': 'Health Med & University Partners',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44407,
#   'upi': 24131427,
#   'netid': 'bs923',
#   'email': 'brie.seferian@yale.edu',
#   'mailbox': 'bs923@connect.yale.edu',
#   'first_name': 'Brie',
#   'last_name': 'Seferian',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19448,
#   'upi': 15780748,
#   'netid': 'qi2',
#   'email': 'qaboos.imran@yale.edu',
#   'mailbox': 'qaboos.imran@bulldogs.yale.edu',
#   'first_name': 'Qaboos',
#   'last_name': 'Imran',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Engineering & Applied Science',
#   'organization_code': 'FAS',
#   'organization': 'Other FAS and Academic Departments',
#   'title': 'Graduate School Student',
#   'address': '9 Hillhouse Avenue, New Haven, CT 06511',
#   'unit_class': 'FASEAS',
#   'unit_code': 'CC0510',
#   'unit': 'CEE Faculty',
#   'postal_address': 'Becton Center, PO BOX 208284, New Haven, CT 06520-8284',
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': 19449,
#   'upi': 24462332,
#   'netid': 'ai329',
#   'email': 'ayyub.imtiaz@yale.edu',
#   'mailbox': 'ai329@connect.yale.edu',
#   'first_name': 'Ayyub',
#   'last_name': 'Imtiaz',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': 'Research Affiliates',
#   'address': None,
#   'unit_class': 'MEDPSY',
#   'unit_code': 'CC1095',
#   'unit': 'Psych Divisions-Ribicoff Labs',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19456,
#   'upi': 17276165,
#   'netid': 'tni3',
#   'email': 'trevor.incerti@yale.edu',
#   'mailbox': 'trevor.incerti@bulldogs.yale.edu',
#   'first_name': 'Trevor',
#   'last_name': 'Incerti',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Political Science',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://politicalscience.yale.edu/people/trevor-incerti',
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://politicalscience.yale.edu/sites/default/files/styles/large/public/pictures/picture-1231-1503698141.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19464,
#   'upi': 14217972,
#   'netid': 'mai7',
#   'email': 'mary.inge@yale.edu',
#   'mailbox': 'mary.inge@bulldogs.yale.edu',
#   'first_name': 'Mary',
#   'last_name': 'Inge',
#   'school_code': 'DI',
#   'school': 'Divinity School',
#   'curriculum': 'Ministry, Professional',
#   'organization_code': 'DIV',
#   'organization': 'Divinity School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19479,
#   'upi': 24321385,
#   'netid': 'mai24',
#   'email': 'matthew.ingwersen@yale.edu',
#   'mailbox': 'matthew.ingwersen@bulldogs.yale.edu',
#   'first_name': 'Matthew',
#   'last_name': 'Ingwersen',
#   'school_code': 'MU',
#   'school': 'School of Music',
#   'curriculum': 'School of Music',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26419,
#   'upi': 17490858,
#   'netid': 'tm768',
#   'email': 'tal.malinovitch@yale.edu',
#   'mailbox': 'tal.malinovitch@bulldogs.yale.edu',
#   'first_name': 'Tal',
#   'last_name': 'Malinovitch',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Mathematics',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://math.yale.edu/people/tal-malinovitch',
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1071-1549401561.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26287,
#   'upi': 24539784,
#   'netid': 'hcm35',
#   'email': 'helen.malley@yale.edu',
#   'mailbox': 'hcm35@connect.yale.edu',
#   'first_name': 'Helen',
#   'last_name': 'Malley',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_9e76f171278394d1835563cee99e1b3c.mp3',
#   'pronouns': 'she/her/hers',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26534,
#   'upi': 24542708,
#   'netid': 'ubm2',
#   'email': 'urmila.mallick@yale.edu',
#   'mailbox': 'ubm2@connect.yale.edu',
#   'first_name': 'Urmila',
#   'last_name': 'Mallick',
#   'school_code': 'FS',
#   'school': 'School of the Environment',
#   'curriculum': 'MESc',
#   'organization_code': 'ENV',
#   'organization': 'School of the Environment',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_9b561c8ac089a047d4943c452a8ee465.mp3',
#   'pronouns': 'She, her, hers',
#   'phonetic_name': 'Oor-mee-la Bah-soo Mah-lick',
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24641087,
#   'netid': 'sm3333',
#   'email': 'stephen.malone@yale.edu',
#   'mailbox': 'sm3333@connect.yale.edu',
#   'first_name': 'Stephen',
#   'last_name': 'Malone',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'ITS',
#   'organization': 'Information Technology Services',
#   'title': 'Consultants',
#   'address': None,
#   'unit_class': 'ITSISO',
#   'unit_code': 'CC0185',
#   'unit': 'Security Director',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26489,
#   'upi': 15998518,
#   'netid': 'gm529',
#   'email': 'gayle.maloney@yale.edu',
#   'mailbox': 'gm529@connect.yale.edu',
#   'first_name': 'Gayle',
#   'last_name': 'Maloney',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': 'Director, Perth OCD Clinic; Assistant Clinical Professor of Psychiatry',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://medicine.yale.edu/profile/gayle_maloney/',
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': 'PhD',
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26523,
#   'upi': 17152099,
#   'netid': 'gm546',
#   'email': 'gwyneth.maloy@yale.edu',
#   'mailbox': 'gm546@connect.yale.edu',
#   'first_name': 'Gwyneth',
#   'last_name': 'Maloy',
#   'school_code': 'MD',
#   'school': 'School of Medicine',
#   'curriculum': 'Medicine',
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26458,
#   'upi': 24034306,
#   'netid': 'jkm57',
#   'email': 'jessica.malsky@yale.edu',
#   'mailbox': 'jkm57@connect.yale.edu',
#   'first_name': 'Jessica',
#   'last_name': 'Malsky',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': 'Family Nurse Practitioner',
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_f90c88cbc20651a2f255cdd659d22896.mp3',
#   'pronouns': 'She, her, hers',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44498,
#   'upi': 24610878,
#   'netid': 'mgs72',
#   'email': 'mason.scisco@yale.edu',
#   'mailbox': 'mgs72@connect.yale.edu',
#   'first_name': 'Mason',
#   'last_name': 'Scisco',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 7814,
#   'upi': 10651066,
#   'netid': 'ic37',
#   'email': 'inger.christensen@yale.edu',
#   'mailbox': 'ic37@connect.yale.edu',
#   'first_name': 'Inger',
#   'last_name': 'Christensen',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': 'Staff Affiliate - YNHH',
#   'address': '221 Whitney Ave, New Haven, CT 06511',
#   'unit_class': 'MEDDER',
#   'unit_code': 'CC1017',
#   'unit': 'General Dermatology',
#   'postal_address': 'Dermatology, PO BOX 208059, New Haven, CT 06520-8059',
#   'office_building': 'Yale University Locations',
#   'cv': None,
#   'profile': 'https://medicine.yale.edu/profile/inger_christensen/',
#   'city': {'address_components': [{'long_name': '221',
#      'short_name': '221',
#      'types': ['street_number']},
#     {'long_name': 'Whitney Avenue',
#      'short_name': 'Whitney Ave',
#      'types': ['route']},
#     {'long_name': 'East Rock',
#      'short_name': 'East Rock',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'New Haven',
#      'short_name': 'New Haven',
#      'types': ['locality', 'political']},
#     {'long_name': 'New Haven County',
#      'short_name': 'New Haven County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Connecticut',
#      'short_name': 'CT',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '06511', 'short_name': '06511', 'types': ['postal_code']},
#     {'long_name': '3760',
#      'short_name': '3760',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '221 Whitney Ave, New Haven, CT 06511, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 41.31696050000001,
#       'lng': -72.9196257},
#      'southwest': {'lat': 41.3165519, 'lng': -72.9199938}},
#     'location': {'lat': 41.3167242, 'lng': -72.91983189999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 41.3181051802915,
#       'lng': -72.91846076970849},
#      'southwest': {'lat': 41.3154072197085, 'lng': -72.92115873029151}}},
#    'place_id': 'ChIJ5RW4s8fZ54kRG_XZMOWDhTM',
#    'types': ['premise']},
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': '2036886445',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point',
#    'coordinates': [-72.91983189999999, 41.3167242]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': 26336,
#   'upi': 24555679,
#   'netid': 'dm2448',
#   'email': 'd.mandelbaum@yale.edu',
#   'mailbox': 'd.mandelbaum@bulldogs.yale.edu',
#   'first_name': 'David',
#   'last_name': 'Mandelbaum',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_e21d28ee161dc9638c55ed2af3f5f0f9.mp3',
#   'pronouns': 'He, Him, His',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 44538,
#   'upi': 17254881,
#   'netid': 'ss3634',
#   'email': 'shalhevet.schwartz@yale.edu',
#   'mailbox': 'shalhevet.schwartz@bulldogs.yale.edu',
#   'first_name': 'Shalhevet',
#   'last_name': 'Schwartz',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '3722 Blackstone Ave\nBronx, NY 10463-1421',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': '3722',
#      'short_name': '3722',
#      'types': ['street_number']},
#     {'long_name': 'Blackstone Avenue',
#      'short_name': 'Blackstone Ave',
#      'types': ['route']},
#     {'long_name': 'Riverdale',
#      'short_name': 'Riverdale',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Bronx',
#      'short_name': 'Bronx',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Bronx County',
#      'short_name': 'Bronx County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '10463', 'short_name': '10463', 'types': ['postal_code']},
#     {'long_name': '1421',
#      'short_name': '1421',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '3722 Blackstone Ave, Bronx, NY 10463, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.8891372,
#       'lng': -73.91119460000002},
#      'southwest': {'lat': 40.8890545, 'lng': -73.9114}},
#     'location': {'lat': 40.8890988, 'lng': -73.9113261},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.89044483029151,
#       'lng': -73.9099483197085},
#      'southwest': {'lat': 40.88774686970851, 'lng': -73.91264628029153}}},
#    'place_id': 'ChIJC3YbvrjzwokRseEdv_ChSog',
#    'types': ['premise']},
#   'year': 2021,
#   'college': 'Branford',
#   'college_code': 'BR',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/ec35cacd0c78b74259f7f16ffe8875fa.jpg',
#   'birthday': 'Dec 31',
#   'major': 'Philosophy',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-73.9113261, 40.8890988]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19529,
#   'upi': 17490059,
#   'netid': 'swi3',
#   'email': 'spencer.irvine@yale.edu',
#   'mailbox': 'spencer.irvine@bulldogs.yale.edu',
#   'first_name': 'Spencer',
#   'last_name': 'Irvine',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Anthropology',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19535,
#   'upi': 10656727,
#   'netid': 'jri2',
#   'email': 'julia.irwin@yale.edu',
#   'mailbox': 'jri2@connect.yale.edu',
#   'first_name': 'Julia',
#   'last_name': 'Irwin',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'UUG',
#   'organization': 'University General',
#   'title': 'Yale Agency Affiliates',
#   'address': None,
#   'unit_class': 'UUGAGE',
#   'unit_code': 'CC1627',
#   'unit': 'Agency Staff - Haskins Labs',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 19551,
#   'upi': 24330123,
#   'netid': 'dni2',
#   'email': 'dirk.isenga@yale.edu',
#   'mailbox': 'dni2@connect.yale.edu',
#   'first_name': 'Dirk',
#   'last_name': 'Isenga',
#   'school_code': 'MG',
#   'school': 'School of Management',
# ...
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-72.9294701, 41.3085224]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': 52920,
#   'upi': 17422824,
#   'netid': 'jm3348',
#   'email': 'joseph.mooney@yale.edu',
#   'mailbox': 'joseph.mooney@bulldogs.yale.edu',
#   'first_name': 'Joseph',
#   'last_name': 'Mooney',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 12926,
#   'upi': 15233331,
#   'netid': 'af527',
#   'email': 'ariel.fein@yale.edu',
#   'mailbox': 'ariel.fein@bulldogs.yale.edu',
#   'first_name': 'Ariel',
#   'last_name': 'Fein',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'FAS',
#   'organization': 'Other FAS and Academic Departments',
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': 'FASHOA',
#   'unit_code': 'CC0559',
#   'unit': 'History of Art',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://arthistory.yale.edu/people/ariel-fein',
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://arthistory.yale.edu/sites/default/files/styles/228x269/public/pictures/picture-113-1608311224.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 36213,
#   'upi': 15729765,
#   'netid': 'mx43',
#   'email': 'mengzhao.xue@yale.edu',
#   'mailbox': 'mengzhao.xue@bulldogs.yale.edu',
#   'first_name': 'Lucy',
#   'last_name': 'Xue',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'ITS',
#   'organization': 'Information Technology Services',
#   'title': 'Commencement 2021 Walker',
#   'address': None,
#   'unit_class': 'ITSHMU',
#   'unit_code': 'CC0184',
#   'unit': 'Health Med & University Partners',
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 1342,
#   'upi': 24605081,
#   'netid': 'zaa9',
#   'email': 'zaharaa.altwaij@yale.edu',
#   'mailbox': 'zaharaa.altwaij@bulldogs.yale.edu',
#   'first_name': 'Zaharaa',
#   'last_name': 'Altwaij',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Dearborn Hts, MI',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Silliman',
#   'college_code': 'SM',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/a71da929d591b1767eb191d1b535423f.jpg',
#   'birthday': 'Oct 29',
#   'major': 'Undeclared',
#   'phone': '2034361825',
#   'access_code': '6-1825',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '29',
#   'birth_month': '10',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 1345,
#   'upi': 24583236,
#   'netid': 'eoa26',
#   'email': 'edgar.alvarado@yale.edu',
#   'mailbox': 'edgar.alvarado@bulldogs.yale.edu',
#   'first_name': 'Edgar',
#   'last_name': 'Alvarado',
#   'school_code': 'AC',
#   'school': 'School of Architecture',
#   'curriculum': 'School of Architecture',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 1347,
#   'upi': 24606033,
#   'netid': 'ia278',
#   'email': 'isabela.alvarado@yale.edu',
#   'mailbox': 'isabela.alvarado@bulldogs.yale.edu',
#   'first_name': 'Isabela',
#   'last_name': 'Alvarado',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '13403 SW 102nd Ln\nMiami, FL 33186-2836',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Silliman',
#   'college_code': 'SM',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/54b3b7480547e6e0cb6c0eadd842e8e4.jpg',
#   'birthday': 'Dec 23',
#   'major': 'Undeclared',
#   'phone': '2034361769',
#   'access_code': '6-1769',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '23',
#   'birth_month': '12',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24679218,
#   'netid': 'ap2656',
#   'email': 'ashley.poole@yale.edu',
#   'mailbox': 'ap2656@connect.yale.edu',
#   'first_name': 'Ashley',
#   'last_name': 'Poole',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': 'Administrative Assistant',
#   'address': '15 York Street, New Haven, CT 06510',
#   'unit_class': 'MEDDER',
#   'unit_code': 'CC1019',
#   'unit': 'DermPath',
#   'postal_address': 'Dermatology, PO BOX 208059, New Haven, CT 06520-8059',
#   'office_building': 'Hunter Building',
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': None,
#   'upi': 24525538,
#   'netid': 'na486',
#   'email': 'natalie.alvarado@yale.edu',
#   'mailbox': 'na486@connect.yale.edu',
#   'first_name': 'Natalie',
#   'last_name': 'Alvarado',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': 'Family Nurse Practitioner',
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 5745,
#   'upi': 24537183,
#   'netid': 'ceb224',
#   'email': 'claire.butler@yale.edu',
#   'mailbox': 'claire.butler@bulldogs.yale.edu',
#   'first_name': 'Claire',
#   'last_name': 'Butler',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Engineering & Applied Science',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2027,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 36237,
#   'upi': 15216212,
#   'netid': 'yx243',
#   'email': 'yaqing.xu@yale.edu',
#   'mailbox': 'yaqing.xu@bulldogs.yale.edu',
#   'first_name': 'Yaqing',
#   'last_name': 'Xu',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Public Health',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24637670,
#   'netid': 'ka596',
#   'email': 'karina.amaya@yale.edu',
#   'mailbox': 'ka596@connect.yale.edu',
#   'first_name': 'Karina',
#   'last_name': 'Amaya',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': 'Project Manager, Pediatric Medical Education',
#   'address': '15 York Street, New Haven, CT 06510',
#   'unit_class': 'MEDPED',
#   'unit_code': 'CC1040',
#   'unit': 'MPEDI-All',
#   'postal_address': 'Dept. of Pediatrics, PO BOX 208064, New Haven, CT 06520-8064',
#   'office_building': 'Lab For Medic, Pediat',
#   'cv': None,
#   'profile': 'https://medicine.yale.edu/profile/karina_amaya/',
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': None,
#   'upi': 24656455,
#   'netid': 'sgf29',
#   'email': 'sam.feineh@yale.edu',
#   'mailbox': 'sgf29@connect.yale.edu',
#   'first_name': 'Sam',
#   'last_name': 'Feineh',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 14402643,
#   'netid': 'aw529',
#   'email': 'aminah.walker@yale.edu',
#   'mailbox': 'aw529@connect.yale.edu',
#   'first_name': 'Aminah',
#   'last_name': 'Walker',
#   'school_code': None,
#   'school': None,
#   'curriculum': None,
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': 'Research Associate',
#   'address': '40 Temple Street, New Haven, CT 06510',
#   'unit_class': 'MEDOPT',
#   'unit_code': 'CC1098',
#   'unit': 'Ophthalmology-All',
#   'postal_address': 'Ophthalmology, PO BOX 208061, New Haven, CT 06520-8061',
#   'office_building': 'Temple St,  40',
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': None,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': 'ChIJ5XCAOkTY54kR7WSyWcZUo_Y'},
#  {'id': 24936,
#   'upi': 24174114,
#   'netid': 'yl2372',
#   'email': 'yun.ling@yale.edu',
#   'mailbox': 'yl2372@connect.yale.edu',
#   'first_name': 'Yun',
#   'last_name': 'Ling',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None}]
