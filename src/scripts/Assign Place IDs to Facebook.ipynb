# %%
# Install Supabase
# !pip3 install supabase

# Init Supabase and read from .env
import os
from supabase import create_client, Client

url: str = os.environ.get("VITE_SUPABASE_URL")
key: str = os.environ.get("VITE_SUPABASE_ANON_KEY")
google_places_key: str = os.environ.get("VITE_GOOGLE_MAP_KEY_SERVER")
supabase: Client = create_client(url, key)
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: supabase in /usr/local/lib/python3.9/site-packages (0.5.6)
# Requirement already satisfied: gotrue<0.6.0,>=0.5.0 in /usr/local/lib/python3.9/site-packages (from supabase) (0.5.0)
# Requirement already satisfied: realtime<0.0.5,>=0.0.4 in /usr/local/lib/python3.9/site-packages (from supabase) (0.0.4)
# Requirement already satisfied: storage3<0.4.0,>=0.3.1 in /usr/local/lib/python3.9/site-packages (from supabase) (0.3.1)
# Requirement already satisfied: postgrest-py<0.11.0,>=0.10.2 in /usr/local/lib/python3.9/site-packages (from supabase) (0.10.2)
# Requirement already satisfied: httpx<0.22.0,>=0.21.3 in /usr/local/lib/python3.9/site-packages (from supabase) (0.21.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /usr/local/lib/python3.9/site-packages (from gotrue<0.6.0,>=0.5.0->supabase) (1.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (2021.10.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (1.2.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (2.0.9)
# Requirement already satisfied: httpcore<0.15.0,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (0.14.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.9/site-packages (from httpx<0.22.0,>=0.21.3->supabase) (1.5.0)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /usr/local/lib/python3.9/site-packages (from postgrest-py<0.11.0,>=0.10.2->supabase) (2.1.0)
# Requirement already satisfied: websockets<10.0,>=9.1 in /usr/local/lib/python3.9/site-packages (from realtime<0.0.5,>=0.0.4->supabase) (9.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /usr/local/lib/python3.9/site-packages (from realtime<0.0.5,>=0.0.4->supabase) (2.8.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /usr/local/lib/python3.9/site-packages (from storage3<0.4.0,>=0.3.1->supabase) (4.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from deprecation<3.0.0,>=2.1.0->postgrest-py<0.11.0,>=0.10.2->supabase) (21.3)
# Requirement already satisfied: h11<0.13,>=0.11 in /usr/local/lib/python3.9/site-packages (from httpcore<0.15.0,>=0.14.0->httpx<0.22.0,>=0.21.3->supabase) (0.12.0)
# Requirement already satisfied: anyio==3.* in /usr/local/lib/python3.9/site-packages (from httpcore<0.15.0,>=0.14.0->httpx<0.22.0,>=0.21.3->supabase) (3.4.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.9/site-packages (from anyio==3.*->httpcore<0.15.0,>=0.14.0->httpx<0.22.0,>=0.21.3->supabase) (3.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<0.0.5,>=0.0.4->supabase) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging->deprecation<3.0.0,>=2.1.0->postgrest-py<0.11.0,>=0.10.2->supabase) (3.0.8)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: There was an error checking the latest version of pip.

# %%
facebook = supabase.table('facebook').select('*').execute().data
facebook

# Filter to give the places that have no place ID but a year
facebook_filtered = [
	    f for f in facebook
	    if f['place_id'] is None and f['year'] is not None
	]
facebook_filtered
# Out:
# [{'id': 51360,
#   'upi': 17511615,
#   'netid': 'sn536',
#   'email': 'seonghoon.noh@yale.edu',
#   'mailbox': 'seonghoon.noh@bulldogs.yale.edu',
#   'first_name': 'Seonghoon',
#   'last_name': 'Noh',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Engineering & Applied Science',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3104,
#   'upi': 17544340,
#   'netid': 'hmb42',
#   'email': 'hannah.batchelor@yale.edu',
#   'mailbox': 'hmb42@connect.yale.edu',
#   'first_name': 'Hannah',
#   'last_name': 'Batchelor',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'MD/PhD Program',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://medicine.yale.edu/inp/profile/hannah_batchelor/',
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4147,
#   'upi': 24585565,
#   'netid': 'dwb48',
#   'email': 'debie.blair@yale.edu',
#   'mailbox': 'dwb48@connect.yale.edu',
#   'first_name': 'Debie',
#   'last_name': 'Blair',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 51343,
#   'upi': 24075769,
#   'netid': 'emn33',
#   'email': 'ellen.nohle@yale.edu',
#   'mailbox': 'emn33@connect.yale.edu',
#   'first_name': 'Ellen',
#   'last_name': 'Nohle',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_704b243b5541010126f5a0a59fdac1c0.mp3',
#   'pronouns': 'Her/she',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31218,
#   'upi': 24176205,
#   'netid': 'hs837',
#   'email': 'helen.stone@yale.edu',
#   'mailbox': 'hs837@connect.yale.edu',
#   'first_name': 'Helen',
#   'last_name': 'Stone',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Microbiology',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31239,
#   'upi': 24275638,
#   'netid': 'as3863',
#   'email': 'ankita.sukthankar@yale.edu',
#   'mailbox': 'as3863@connect.yale.edu',
#   'first_name': 'Ankita',
#   'last_name': 'Sukthankar',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31171,
#   'upi': 24571795,
#   'netid': 'ajs324',
#   'email': 'a.sung@yale.edu',
#   'mailbox': 'a.sung@bulldogs.yale.edu',
#   'first_name': 'Andrew',
#   'last_name': 'Sung',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Rancho Palos Verdes, CA',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Pauli Murray',
#   'college_code': 'MY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/4c644bb3eebd64acaa8a7a6a74429961.jpg',
#   'birthday': 'Jun 1',
#   'major': 'Undeclared',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '1',
#   'birth_month': '6',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31227,
#   'upi': 24589611,
#   'netid': 'cat64',
#   'email': 'carlos.torres@yale.edu',
#   'mailbox': 'carlos.torres@bulldogs.yale.edu',
#   'first_name': 'Carlos',
#   'last_name': 'Torres',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'NV',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Timothy Dwight',
#   'college_code': 'TD',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/b9f811c45bd44bffce3f6fdccfe39a01.jpg',
#   'birthday': None,
#   'major': 'Undeclared',
#   'phone': '2034361685',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31155,
#   'upi': 24349180,
#   'netid': 'njt23',
#   'email': 'nathan.tribble@yale.edu',
#   'mailbox': 'njt23@connect.yale.edu',
#   'first_name': 'Nathan',
#   'last_name': 'Tribble',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4198,
#   'upi': 17255051,
#   'netid': 'ecb67',
#   'email': 'evan.blasy@yale.edu',
#   'mailbox': 'evan.blasy@bulldogs.yale.edu',
#   'first_name': 'Evan',
#   'last_name': 'Blasy',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '69 Catherine Vw\nRichmond Hill, GA 31324-7302',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': '69',
#      'short_name': '69',
#      'types': ['street_number']},
#     {'long_name': 'Catherine View',
#      'short_name': 'Catherine View',
#      'types': ['route']},
#     {'long_name': 'Richmond Hill',
#      'short_name': 'Richmond Hill',
#      'types': ['locality', 'political']},
#     {'long_name': 'Bryan County',
#      'short_name': 'Bryan County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Georgia',
#      'short_name': 'GA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '31324', 'short_name': '31324', 'types': ['postal_code']},
#     {'long_name': '7302',
#      'short_name': '7302',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '69 Catherine View, Richmond Hill, GA 31324, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 31.8273116,
#       'lng': -81.2692036},
#      'southwest': {'lat': 31.8270863, 'lng': -81.2694381}},
#     'location': {'lat': 31.8272085, 'lng': -81.2693051},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 31.8285479302915,
#       'lng': -81.26797186970849},
#      'southwest': {'lat': 31.8258499697085, 'lng': -81.27066983029151}}},
#    'place_id': 'ChIJL5SvxXUR-4gRHp9WrAT9CgU',
#    'types': ['premise']},
#   'year': 2021,
#   'college': 'Benjamin Franklin',
#   'college_code': 'BF',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/f6f355261fe1275282df35eddf170924.jpg',
#   'birthday': 'Oct 31',
#   'major': 'Computer Science',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-81.2693051, 31.8272085]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4194,
#   'upi': 17222836,
#   'netid': 'hlb34',
#   'email': 'hanna.blankemeier@yale.edu',
#   'mailbox': 'hanna.blankemeier@bulldogs.yale.edu',
#   'first_name': 'Hanna',
#   'last_name': 'Blankemeier',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '240 S Euclid Ave\nOak Park, IL 60302-3206',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': '240',
#      'short_name': '240',
#      'types': ['street_number']},
#     {'long_name': 'South Euclid Avenue',
#      'short_name': 'S Euclid Ave',
#      'types': ['route']},
#     {'long_name': 'Oak Park',
#      'short_name': 'Oak Park',
#      'types': ['locality', 'political']},
#     {'long_name': 'Oak Park Township',
#      'short_name': 'Oak Park Township',
#      'types': ['administrative_area_level_3', 'political']},
#     {'long_name': 'Cook County',
#      'short_name': 'Cook County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Illinois',
#      'short_name': 'IL',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '60302', 'short_name': '60302', 'types': ['postal_code']},
#     {'long_name': '3206',
#      'short_name': '3206',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '240 S Euclid Ave, Oak Park, IL 60302, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 41.8835835,
#       'lng': -87.79222109999999},
#      'southwest': {'lat': 41.8834407, 'lng': -87.7924362}},
#     'location': {'lat': 41.88349849999999, 'lng': -87.792357},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 41.8848610802915,
#       'lng': -87.79097966970849},
#      'southwest': {'lat': 41.8821631197085, 'lng': -87.7936776302915}}},
#    'place_id': 'ChIJ9369yr40DogR2rJhMr2c8JY',
#    'types': ['premise']},
#   'year': 2021,
#   'college': 'Pauli Murray',
#   'college_code': 'MY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/ea44904c3d764f5918f839907eea1eca.jpg',
#   'birthday': 'Aug 5',
#   'major': 'Anthropology',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point',
#    'coordinates': [-87.792357, 41.88349849999999]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3120,
#   'upi': 17091477,
#   'netid': 'adb64',
#   'email': 'alexander.batson@yale.edu',
#   'mailbox': 'alexander.batson@bulldogs.yale.edu',
#   'first_name': 'Alexander',
#   'last_name': 'Batson',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'History',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://history.yale.edu/people/alexander-batson',
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://history.yale.edu/sites/default/files/styles/portrait/public/pictures/picture-1431-1605630909.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4180,
#   'upi': 24580737,
#   'netid': 'chb49',
#   'email': 'carlos.blanco@yale.edu',
#   'mailbox': 'carlos.blanco@bulldogs.yale.edu',
#   'first_name': 'Carlos',
#   'last_name': 'Blanco',
#   'school_code': 'AC',
#   'school': 'School of Architecture',
#   'curriculum': 'School of Architecture',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 51334,
#   'upi': 24524603,
#   'netid': 'ln327',
#   'email': 'laura.noratoprieto@yale.edu',
#   'mailbox': 'ln327@connect.yale.edu',
#   'first_name': 'Laura',
#   'last_name': 'Norato Prieto',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 51316,
#   'upi': 24520914,
#   'netid': 'ncn7',
#   'email': 'naomi.norbraten@yale.edu',
#   'mailbox': 'naomi.norbraten@bulldogs.yale.edu',
#   'first_name': 'Naomi',
#   'last_name': 'Norbraten',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '551 Bethesda Church Rd\nCarrollton, GA 30117-5883',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Morse',
#   'college_code': 'MC',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/2127acd479b0604d0b5f432e2f0eca94.jpg',
#   'birthday': 'Oct 29',
#   'major': 'Undeclared',
#   'phone': '2034363185',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '29',
#   'birth_month': '10',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31250,
#   'upi': 24587962,
#   'netid': 'as3987',
#   'email': 'anand.srinivasan@yale.edu',
#   'mailbox': 'anand.srinivasan@bulldogs.yale.edu',
#   'first_name': 'Anand',
#   'last_name': 'Srinivasan',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '2031 N Decatur Rd NE\nAtlanta, GA 30307-1126',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Pauli Murray',
#   'college_code': 'MY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/b0a25d196d8a9a39eab7b372eb777b00.jpg',
#   'birthday': 'Apr 16',
#   'major': 'Undeclared',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '16',
#   'birth_month': '4',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 36335,
#   'upi': 17629017,
#   'netid': 'xx99',
#   'email': 'xin.xin@yale.edu',
#   'mailbox': 'xin.xin@bulldogs.yale.edu',
#   'first_name': 'Xin',
#   'last_name': 'Xin',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Comb Progs:Biol&Biomed Science',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Statistician II',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://medicine.yale.edu/profile/xin_xin/',
#   'city': None,
#   'year': 2027,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': 'MS, MA',
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4224,
#   'upi': 17256734,
#   'netid': 'mpb53',
#   'email': 'michael.blicher@yale.edu',
#   'mailbox': 'michael.blicher@bulldogs.yale.edu',
#   'first_name': 'Michael',
#   'last_name': 'Blicher',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Sudbury, MA',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': 'Sudbury',
#      'short_name': 'Sudbury',
#      'types': ['locality', 'political']},
#     {'long_name': 'Middlesex County',
#      'short_name': 'Middlesex County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Massachusetts',
#      'short_name': 'MA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Sudbury, MA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.4367461,
#       'lng': -71.3618259},
#      'southwest': {'lat': 42.340883, 'lng': -71.484949}},
#     'location': {'lat': 42.3834278, 'lng': -71.4161725},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 42.4367461, 'lng': -71.3618259},
#      'southwest': {'lat': 42.340883, 'lng': -71.484949}}},
#    'place_id': 'ChIJT5eL20-O44kRwmpfwmzo5d8',
#    'types': ['locality', 'political']},
#   'year': 2021,
#   'college': 'Pauli Murray',
#   'college_code': 'MY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/c33e574634c9d78a5be506ea3b8ab82f.jpg',
#   'birthday': 'Sep 24',
#   'major': 'Cognitive Science',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-71.4161725, 42.3834278]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 51303,
#   'upi': 17513230,
#   'netid': 'kn363',
#   'email': 'katelyn.noronha@yale.edu',
#   'mailbox': 'katelyn.noronha@bulldogs.yale.edu',
#   'first_name': 'Katelyn',
#   'last_name': 'Noronha',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Molecular Biophysics & Biochem',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31393,
#   'upi': 24058616,
#   'netid': 'veu3',
#   'email': 'victor.uko@yale.edu',
#   'mailbox': 'veu3@connect.yale.edu',
#   'first_name': 'Victor',
#   'last_name': 'Uko',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3201,
#   'upi': 24586143,
#   'netid': 'ab3445',
#   'email': 'allyson.beach@yale.edu',
#   'mailbox': 'ab3445@connect.yale.edu',
#   'first_name': 'Allyson',
#   'last_name': 'Beach',
#   'school_code': 'FS',
#   'school': 'School of the Environment',
#   'curriculum': 'MEM',
#   'organization_code': 'ENV',
#   'organization': 'School of the Environment',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_3df349cbbea43b2f290938d5da14f634.mp3',
#   'pronouns': 'she/her',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3214,
#   'upi': 24088298,
#   'netid': 'srb99',
#   'email': 'sophie.beal@yale.edu',
#   'mailbox': 'sophie.beal@bulldogs.yale.edu',
#   'first_name': 'Sophie',
#   'last_name': 'Beal',
#   'school_code': 'DI',
#   'school': 'Divinity School',
#   'curriculum': 'Ministry, Professional',
#   'organization_code': 'DIV',
#   'organization': 'Divinity School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_d14b5f59117c52bc914e8f067c819dab.mp3',
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 46656,
#   'upi': 24278018,
#   'netid': 'kmr76',
#   'email': 'kaitlyn.roberts@yale.edu',
#   'mailbox': 'kmr76@connect.yale.edu',
#   'first_name': 'Kaitlyn',
#   'last_name': 'Roberts',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': 'Pediatric NP Primary Care',
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31412,
#   'upi': 24327403,
#   'netid': 'cfs43',
#   'email': 'chris.song@yale.edu',
#   'mailbox': 'chris.song@bulldogs.yale.edu',
#   'first_name': 'Chris',
#   'last_name': 'Song',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': 'Pauli Murray',
#   'college_code': 'MY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/3f93a90d6955cc65be47e2f394698b22.jpg',
#   'birthday': None,
#   'major': 'Cognitive Science',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31324,
#   'upi': 24363035,
#   'netid': 'ohs4',
#   'email': 'olivia.stillman@yale.edu',
#   'mailbox': 'ohs4@connect.yale.edu',
#   'first_name': 'Olivia',
#   'last_name': 'Stillman',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': "Nurse Midwifery/Women's Health",
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31371,
#   'upi': 24519911,
#   'netid': 'wbt6',
#   'email': 'whitney.toutenhoofd@yale.edu',
#   'mailbox': 'whitney.toutenhoofd@bulldogs.yale.edu',
#   'first_name': 'Whitney',
#   'last_name': 'Toutenhoofd',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '935 Lincoln Pl\nBoulder, CO 80302-7233',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Trumbull',
#   'college_code': 'TC',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/2729728aea09cd7f3b1e9c3d95c74926.jpg',
#   'birthday': 'Jun 26',
#   'major': 'Undeclared',
#   'phone': '2034360301',
#   'access_code': '6-0301',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '26',
#   'birth_month': '6',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31363,
#   'upi': 17265608,
#   'netid': 'jlt76',
#   'email': 'jennifer.troiano@yale.edu',
#   'mailbox': 'jennifer.troiano@bulldogs.yale.edu',
#   'first_name': 'Jennifer',
#   'last_name': 'Troiano',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Chemistry',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 36291,
#   'upi': 24070159,
#   'netid': 'rx43',
#   'email': 'chris.xu@yale.edu',
#   'mailbox': 'chris.xu@bulldogs.yale.edu',
#   'first_name': 'Chris',
#   'last_name': 'Xu',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Statistics and Data Science',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3247,
#   'upi': 17512380,
#   'netid': 'ceb88',
#   'email': 'caitie.beattie@yale.edu',
#   'mailbox': 'caitie.beattie@bulldogs.yale.edu',
#   'first_name': 'Caitie',
#   'last_name': 'Beattie',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Physics',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate Student Year 3 (Harris, John)',
#   'address': 'WL-W 301',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://physics.yale.edu/people/caitie-beattie',
#   'city': 0,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://physics.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-3193-1591894341.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': '2034322043',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3274,
#   'upi': 24319379,
#   'netid': 'wcb38',
#   'email': 'william.beck@yale.edu',
#   'mailbox': 'william.beck@bulldogs.yale.edu',
#   'first_name': 'William',
#   'last_name': 'Beck',
#   'school_code': 'AC',
#   'school': 'School of Architecture',
#   'curriculum': 'School of Architecture',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4379,
#   'upi': 24520387,
#   'netid': 'db2443',
#   'email': 'diego.bolanos@yale.edu',
#   'mailbox': 'diego.bolanos@bulldogs.yale.edu',
#   'first_name': 'Diego',
#   'last_name': 'Bolanos',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '294 N Livingston Ave\nLivingston, NJ 07039-1252',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Saybrook',
#   'college_code': 'SY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/db5deb1734edbdae5332e0593fc13945.jpg',
#   'birthday': 'Nov 16',
#   'major': 'Undeclared',
#   'phone': '2034360940',
#   'access_code': '6-0940',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '16',
#   'birth_month': '11',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 27373,
#   'upi': 24601477,
#   'netid': 'atn28',
#   'email': 'andrew.nupp@yale.edu',
#   'mailbox': 'andrew.nupp@bulldogs.yale.edu',
#   'first_name': 'Andrew',
#   'last_name': 'Nupp',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '1385 Bakers Creek Rd\nRussellville, AR 72802-8053',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Morse',
#   'college_code': 'MC',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/f8c9567b1873fb08419c5e88e4620143.jpg',
#   'birthday': 'Jan 27',
#   'major': 'Undeclared',
#   'phone': '2034363184',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '27',
#   'birth_month': '1',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3309,
#   'upi': 24290785,
#   'netid': 'jab435',
#   'email': 'jessica.bediako@yale.edu',
#   'mailbox': 'jab435@connect.yale.edu',
#   'first_name': 'Jessica',
#   'last_name': 'Bediako',
#   'school_code': 'FS',
#   'school': 'School of the Environment',
#   'curriculum': 'MEM',
#   'organization_code': 'ENV',
#   'organization': 'School of the Environment',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_d3c5b4552b0b9d5fdd1bb0188d49a565.mp3',
#   'pronouns': 'She',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4550,
#   'upi': 24519197,
#   'netid': 'tb776',
#   'email': 'thairol.borrego@yale.edu',
#   'mailbox': 'thairol.borrego@bulldogs.yale.edu',
#   'first_name': 'Thairol',
#   'last_name': 'Borrego',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '2650 W 11th Ct Apt 311\nHialeah, FL 33010-6106',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Jonathan Edwards',
#   'college_code': 'JE',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/f22eb14bfc3fdab1f3b545d3b324b65e.jpg',
#   'birthday': 'Apr 28',
#   'major': 'Undeclared',
#   'phone': '2034360127',
#   'access_code': '6-0127',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '28',
#   'birth_month': '4',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 4581,
#   'upi': 17516970,
#   'netid': 'hjb34',
#   'email': 'hannah.bossi@yale.edu',
#   'mailbox': 'hannah.bossi@bulldogs.yale.edu',
#   'first_name': 'Hannah',
#   'last_name': 'Bossi',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Physics',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student Year 3 (Harris, John)',
#   'address': 'WL-W 301',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://physics.yale.edu/people/hannah-bossi',
#   'city': 0,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://physics.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-3196-1535123905.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': '2034322043',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 27370,
#   'upi': 24579802,
#   'netid': 'an665',
#   'email': 'abdurrahman.nur@yale.edu',
#   'mailbox': 'abdurrahman.nur@bulldogs.yale.edu',
#   'first_name': 'Abdurrahman',
#   'last_name': 'Nur',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Sociology',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 27372,
#   'upi': 17074698,
#   'netid': 'atn23',
#   'email': 'ahmed.nur@yale.edu',
#   'mailbox': 'ahmed.nur@bulldogs.yale.edu',
#   'first_name': 'Ahmed',
#   'last_name': 'Nur',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Religious Studies',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://religiousstudies.yale.edu/people/ahmed-nur',
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 27224,
#   'upi': 24596241,
#   'netid': 'jln43',
#   'email': 'jason.nuttle@yale.edu',
#   'mailbox': 'jason.nuttle@bulldogs.yale.edu',
#   'first_name': 'Jason',
#   'last_name': 'Nuttle',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '5744 S Chanberry Ln\nRogers, AR 72758-8673',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Ezra Stiles',
#   'college_code': 'ES',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/93de5cbadc75e97f82bdac7415c735cb.jpg',
#   'birthday': 'Dec 22',
#   'major': 'Undeclared',
#   'phone': '2034360168',
#   'access_code': '6-0168',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '22',
#   'birth_month': '12',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 31938,
#   'upi': 24592246,
#   'netid': 'st888',
#   'email': 'shrea.tyagi@yale.edu',
#   'mailbox': 'shrea.tyagi@bulldogs.yale.edu',
#   'first_name': 'Shrea',
#   'last_name': 'Tyagi',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '4604 W Memphis St\nBroken Arrow, OK 74012-8982',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Silliman',
#   'college_code': 'SM',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/f4b2546e419cd9ab2c67d7e22c740915.jpg',
#   'birthday': 'Dec 1',
#   'major': 'Undeclared',
#   'phone': '2034361731',
#   'access_code': '6-1731',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
# ...
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 6241,
#   'upi': 24332843,
#   'netid': 'tc759',
#   'email': 'tyler.caponigro@yale.edu',
#   'mailbox': 'tc759@connect.yale.edu',
#   'first_name': 'Tyler',
#   'last_name': 'Caponigro',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 9744,
#   'upi': 24083980,
#   'netid': 'khd8',
#   'email': 'karan.daryananidaryanani@yale.edu',
#   'mailbox': 'karan.daryananidaryanani@bulldogs.yale.edu',
#   'first_name': 'Karan',
#   'last_name': 'Daryanani Daryanani',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'International&Devlpmnt Econ',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 9740,
#   'upi': 17382738,
#   'netid': 'pad55',
#   'email': 'poonam.daryani@yale.edu',
#   'mailbox': 'pad55@connect.yale.edu',
#   'first_name': 'Poonam',
#   'last_name': 'Daryani',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_68846fa21b9b6451d70898ba09c98eba.mp3',
#   'pronouns': 'she/her/hers',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 27990,
#   'upi': 24292213,
#   'netid': 'vr299',
#   'email': 'valentina.rangelangarita@yale.edu',
#   'mailbox': 'valentina.rangelangarita@bulldogs.yale.edu',
#   'first_name': 'Valentina',
#   'last_name': 'Rangel Angarita',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Chemistry',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 28469,
#   'upi': 24605795,
#   'netid': 'zer4',
#   'email': 'zara.ranglin@yale.edu',
#   'mailbox': 'zara.ranglin@bulldogs.yale.edu',
#   'first_name': 'Zara',
#   'last_name': 'Ranglin',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Kingston 6, Jamaica',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Davenport',
#   'college_code': 'DC',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/370889b0b9817dd3698d56247428b838.jpg',
#   'birthday': 'Apr 12',
#   'major': 'Undeclared',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '12',
#   'birth_month': '4',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32427,
#   'upi': 13933834,
#   'netid': 'lmu3',
#   'email': 'lindsey.uniat@yale.edu',
#   'mailbox': 'lindsey.uniat@bulldogs.yale.edu',
#   'first_name': 'Lindsey',
#   'last_name': 'Uniat',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Economics',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://economics.yale.edu/people/graduate-students/lindsey-uniat',
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 37211,
#   'upi': 24578918,
#   'netid': 'mww28',
#   'email': 'matthew.wilde@yale.edu',
#   'mailbox': 'matthew.wilde@bulldogs.yale.edu',
#   'first_name': 'Matthew',
#   'last_name': 'Wilde',
#   'school_code': 'AC',
#   'school': 'School of Architecture',
#   'curriculum': 'School of Architecture',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 37212,
#   'upi': 17663561,
#   'netid': 'sw979',
#   'email': 'sw979@yale.edu',
#   'mailbox': 'sw979@bulldogs.yale.edu',
#   'first_name': 'Sierra',
#   'last_name': 'Wilde',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Physics',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student Year 1',
#   'address': 'SPL 76/SPL 58',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://physics.yale.edu/people/sierra-wilde',
#   'city': 0,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://physics.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-3542-1588173604.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 37208,
#   'upi': 24530451,
#   'netid': 'alw89',
#   'email': 'amber.wilder@yale.edu',
#   'mailbox': 'alw89@connect.yale.edu',
#   'first_name': 'Amber',
#   'last_name': 'Wilder',
#   'school_code': 'PA',
#   'school': 'Physician Associate Program',
#   'curriculum': 'Physician Associate Program',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 37157,
#   'upi': 24540804,
#   'netid': 'akw56',
#   'email': 'alexa.williams@yale.edu',
#   'mailbox': 'alexa.williams@bulldogs.yale.edu',
#   'first_name': 'Alexa',
#   'last_name': 'Williams',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Chemistry',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2027,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 37155,
#   'upi': 17520693,
#   'netid': 'amw238',
#   'email': 'alicia.williams@yale.edu',
#   'mailbox': 'alicia.williams@bulldogs.yale.edu',
#   'first_name': 'Alicia',
#   'last_name': 'Williams',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Public Health',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2027,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 37135,
#   'upi': 24279956,
#   'netid': 'drw42',
#   'email': 'dylan.williams@yale.edu',
#   'mailbox': 'drw42@connect.yale.edu',
#   'first_name': 'Dylan',
#   'last_name': 'Williams',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': 'Psychiatric-Mental Hlth Nursng',
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 28015,
#   'upi': 24322881,
#   'netid': 'sr2325',
#   'email': 'shuyu.rao@yale.edu',
#   'mailbox': 'shuyu.rao@bulldogs.yale.edu',
#   'first_name': 'Shuyu',
#   'last_name': 'Rao',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Statistics',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://statistics.yale.edu/people/shuyu-rao',
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 9809,
#   'upi': 24281503,
#   'netid': 'md2483',
#   'email': 'marc.david@yale.edu',
#   'mailbox': 'md2483@connect.yale.edu',
#   'first_name': 'Marc',
#   'last_name': 'David Sanche',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None}]

# %%
# For each filtered place, get the place ID, description, longitude, and latitude from the Google Places API using the address field
import requests
import json

facebook_filtered_with_place_id = []
for f in facebook_filtered[0:1]:
	address = f['address']
	url = f'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={address}&inputtype=textquery&fields=place_id,formatted_address,name,geometry&key={google_places_key}'
	response = requests.get(url)
	data = json.loads(response.text)
	print(data)
	place_id = data['candidates'][0]['place_id']
	f['place_id'] = place_id
	facebook_filtered_with_place_id.append(f)
# Out:
# {'candidates': [{'formatted_address': '20410 E Vejar Rd, Walnut, CA 91789, United States', 'geometry': {'location': {'lat': 34.0201671, 'lng': -117.8580158}, 'viewport': {'northeast': {'lat': 34.02154347989271, 'lng': -117.8566999201073}, 'southwest': {'lat': 34.01884382010727, 'lng': -117.8593995798927}}}, 'name': 'none', 'place_id': 'ChIJA_0NTcgrw4ARPn9a0xohjws'}], 'status': 'OK'}

# %%
facebook = supabase.table('facebook').select('*').execute().data
facebook

# Filter to give the places that have no place ID but a year
facebook_filtered = [
	    f for f in facebook
	    if f['place_id'] is None and f['year'] is not None
	]
facebook_filtered
# Out:
# [{'id': 28952,
#   'upi': 17275485,
#   'netid': 'jdr87',
#   'email': 'jason.ray@yale.edu',
#   'mailbox': 'jason.ray@bulldogs.yale.edu',
#   'first_name': 'Jason',
#   'last_name': 'Ray',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Chemistry',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26593,
#   'upi': 24486013,
#   'netid': 'im368',
#   'email': 'irene.manziniceinar@yale.edu',
#   'mailbox': 'irene.manziniceinar@bulldogs.yale.edu',
#   'first_name': 'Irene',
#   'last_name': 'Manzini Ceinar',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Architecture',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26602,
#   'upi': 24003077,
#   'netid': 'ym356',
#   'email': 'alice.mao@yale.edu',
#   'mailbox': 'alice.mao@bulldogs.yale.edu',
#   'first_name': 'Alice',
#   'last_name': 'Mao',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Morse',
#   'college_code': 'MC',
#   'leave': True,
#   'eli_whitney': False,
#   'image': None,
#   'birthday': None,
#   'major': 'Art',
#   'phone': '2034361096',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3060,
#   'upi': 24319226,
#   'netid': 'jb3433',
#   'email': 'janani.baskaran@yale.edu',
#   'mailbox': 'janani.baskaran@bulldogs.yale.edu',
#   'first_name': 'Janani',
#   'last_name': 'Baskaran',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Engineering & Applied Science',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3061,
#   'upi': 17262973,
#   'netid': 'mjb273',
#   'email': 'maia.baskerville@yale.edu',
#   'mailbox': 'maia.baskerville@bulldogs.yale.edu',
#   'first_name': 'Maia',
#   'last_name': 'Baskerville',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Microbiology',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54390,
#   'upi': 24352240,
#   'netid': 'djm243',
#   'email': 'dan.mcglade@yale.edu',
#   'mailbox': 'djm243@connect.yale.edu',
#   'first_name': 'Dan',
#   'last_name': 'McGlade',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Interdpt Neuroscience Pgm',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26643,
#   'upi': 24586517,
#   'netid': 'jam455',
#   'email': 'jonathan.maresca@yale.edu',
#   'mailbox': 'jonathan.maresca@bulldogs.yale.edu',
#   'first_name': 'Jonathan',
#   'last_name': 'Maresca',
#   'school_code': 'DI',
#   'school': 'Divinity School',
#   'curriculum': 'Ministry, Professional',
#   'organization_code': 'DIV',
#   'organization': 'Divinity School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54436,
#   'upi': 17278936,
#   'netid': 'lam252',
#   'email': 'lucy.mcewan@yale.edu',
#   'mailbox': 'lucy.mcewan@bulldogs.yale.edu',
#   'first_name': 'Lucy',
#   'last_name': 'McEwan',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '79 Mountfield Crescent,\nLiverpool, L25 4AE\nUnited Kingdom',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': '79',
#      'short_name': '79',
#      'types': ['street_number']},
#     {'long_name': 'Mountfield Crescent',
#      'short_name': 'Mountfield Cres',
#      'types': ['route']},
#     {'long_name': 'Gateacre',
#      'short_name': 'Gateacre',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Liverpool',
#      'short_name': 'Liverpool',
#      'types': ['postal_town']},
#     {'long_name': 'Merseyside',
#      'short_name': 'Merseyside',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'England',
#      'short_name': 'England',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United Kingdom',
#      'short_name': 'GB',
#      'types': ['country', 'political']},
#     {'long_name': 'L25 3TA',
#      'short_name': 'L25 3TA',
#      'types': ['postal_code']}],
#    'formatted_address': '79 Mountfield Cres, Gateacre, Liverpool L25 3TA, UK',
#    'geometry': {'location': {'lat': 53.3858766, 'lng': -2.8693336},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 53.38722558029149,
#       'lng': -2.867984619708498},
#      'southwest': {'lat': 53.3845276197085, 'lng': -2.870682580291502}}},
#    'place_id': 'ChIJ-bNk1ZYfe0gRM4zC5SdEZ84',
#    'plus_code': {'compound_code': '94PJ+97 Liverpool, UK',
#     'global_code': '9C5V94PJ+97'},
#    'types': ['street_address']},
#   'year': 2021,
#   'college': 'Branford',
#   'college_code': 'BR',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/8610ab0e8da4c3a48c65acf2b2bde0bb.jpg',
#   'birthday': 'Jul 17',
#   'major': 'Physics',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-2.8693336, 53.3858766]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54403,
#   'upi': 24527816,
#   'netid': 'nsm29',
#   'email': 'nyla.mcgill@yale.edu',
#   'mailbox': 'nyla.mcgill@bulldogs.yale.edu',
#   'first_name': 'Nyla',
#   'last_name': 'McGill',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '3534 Cole Mill Rd\nCharlotte, NC 28270-1116',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Jonathan Edwards',
#   'college_code': 'JE',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/7686ae8a02917f2352d252649b96fe36.jpg',
#   'birthday': 'Apr 11',
#   'major': 'Undeclared',
#   'phone': '2034360115',
#   'access_code': '6-0115',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '11',
#   'birth_month': '4',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 30525,
#   'upi': 17461873,
#   'netid': 'nr394',
#   'email': 'nadav.raziel@yale.edu',
#   'mailbox': 'nadav.raziel@bulldogs.yale.edu',
#   'first_name': 'Nadav',
#   'last_name': 'Raziel',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '9, Ha-Oranim\nHod ha-Sharon, 4526320\nIsrael',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': '9',
#      'short_name': '9',
#      'types': ['street_number']},
#     {'long_name': 'HaOranim Street',
#      'short_name': 'HaOranim St',
#      'types': ['route']},
#     {'long_name': 'Hod Hasharon',
#      'short_name': 'Hod Hasharon',
#      'types': ['locality', 'political']},
#     {'long_name': 'Petach Tikva',
#      'short_name': 'Petach Tikva',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Center District',
#      'short_name': 'Center District',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Israel',
#      'short_name': 'IL',
#      'types': ['country', 'political']}],
#    'formatted_address': 'HaOranim St 9, Hod Hasharon, Israel',
#    'geometry': {'location': {'lat': 32.154464, 'lng': 34.8885233},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 32.15581298029149,
#       'lng': 34.8898722802915},
#      'southwest': {'lat': 32.15311501970849, 'lng': 34.8871743197085}}},
#    'partial_match': True,
#    'place_id': 'ChIJvY4LtYs3HRUR-Eabdocztes',
#    'plus_code': {'compound_code': '5V3Q+QC Hod Hasharon, Israel',
#     'global_code': '8G4P5V3Q+QC'},
#    'types': ['street_address']},
#   'year': 2022,
#   'college': 'Berkeley',
#   'college_code': 'BK',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/e1388d8d43cf4abefded225224e4b964.jpg',
#   'birthday': 'Oct 10',
#   'major': 'Economics',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [34.8885233, 32.154464]},
#   'birth_day': '10',
#   'birth_month': '10',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54401,
#   'upi': 24357221,
#   'netid': 'kmm272',
#   'email': 'kelly.mcglinchey@yale.edu',
#   'mailbox': 'kmm272@connect.yale.edu',
#   'first_name': 'Kelly',
#   'last_name': 'McGlinchey',
#   'school_code': 'FS',
#   'school': 'School of the Environment',
#   'curriculum': 'MEM',
#   'organization_code': 'ENV',
#   'organization': 'School of the Environment',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_578b1ccadea5813a4f98010f3fff8e97.mp3',
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54377,
#   'upi': 14757110,
#   'netid': 'cm855',
#   'email': 'christopher.mcgowan@yale.edu',
#   'mailbox': 'christopher.mcgowan@bulldogs.yale.edu',
#   'first_name': 'Christopher',
#   'last_name': 'McGowan',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'English Language & Literature',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 39,
#   'upi': 17573087,
#   'netid': 'mma79',
#   'email': 'mara.anderson@yale.edu',
#   'mailbox': 'mma79@connect.yale.edu',
#   'first_name': 'Mara',
#   'last_name': 'Anderson',
#   'school_code': 'PA',
#   'school': 'Physician Associate Program',
#   'curriculum': 'Physician Associate Program',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2020,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3089,
#   'upi': 24314398,
#   'netid': 'bab228',
#   'email': 'basil.bastaki@yale.edu',
#   'mailbox': 'basil.bastaki@bulldogs.yale.edu',
#   'first_name': 'Basil',
#   'last_name': 'Bastaki',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Political Science',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://politicalscience.yale.edu/people/basil-bastaki',
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://politicalscience.yale.edu/sites/default/files/styles/large/public/pictures/picture-3066-1600651727.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_d20c438b0b8c91060157dd45c24ecc6b.mp3',
#   'pronouns': 'He / him / his',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3091,
#   'upi': 24323408,
#   'netid': 'ab3357',
#   'email': 'ann.basting@yale.edu',
#   'mailbox': 'ann.basting@bulldogs.yale.edu',
#   'first_name': 'Ann',
#   'last_name': 'Basting',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3093,
#   'upi': 24310063,
#   'netid': 'ab3355',
#   'email': 'aakash.basu@yale.edu',
#   'mailbox': 'aakash.basu@bulldogs.yale.edu',
#   'first_name': 'Aakash',
#   'last_name': 'Basu',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Interdpt Neuroscience Pgm',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://medicine.yale.edu/inp/profile/aakash_basu/',
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 29461,
#   'upi': 17308312,
#   'netid': 'bdr27',
#   'email': 'benjamin.reattoir@yale.edu',
#   'mailbox': 'benjamin.reattoir@bulldogs.yale.edu',
#   'first_name': 'Benjamin',
#   'last_name': 'Reattoir',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Sault Sainte Marie, MI 49783-1120',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': 'Sault Ste. Marie',
#      'short_name': 'Sault Ste. Marie',
#      'types': ['locality', 'political']},
#     {'long_name': 'Chippewa County',
#      'short_name': 'Chippewa County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Michigan',
#      'short_name': 'MI',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '49783', 'short_name': '49783', 'types': ['postal_code']}],
#    'formatted_address': 'Sault Ste. Marie, MI 49783, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 46.509099,
#       'lng': -84.28170709999999},
#      'southwest': {'lat': 46.462519, 'lng': -84.46717199999999}},
#     'location': {'lat': 46.49771150000001, 'lng': -84.3475876},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 46.509099, 'lng': -84.28170709999999},
#      'southwest': {'lat': 46.462519, 'lng': -84.46717199999999}}},
#    'place_id': 'ChIJpQ4yEXs5Nk0RB1yxaGuUWJo',
#    'types': ['locality', 'political']},
#   'year': 2022,
#   'college': 'Jonathan Edwards',
#   'college_code': 'JE',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/12d9e86003162cb312c854d437b7d553.jpg',
#   'birthday': 'Jan 21',
#   'major': 'History',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point',
#    'coordinates': [-84.3475876, 46.49771150000001]},
#   'birth_day': '21',
#   'birth_month': '1',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3100,
#   'upi': 24299098,
#   'netid': 'jb3425',
#   'email': 'jad.bataha@yale.edu',
#   'mailbox': 'jad.bataha@bulldogs.yale.edu',
#   'first_name': 'Jad',
#   'last_name': 'Bataha',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': 'Pauli Murray',
#   'college_code': 'MY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/63ac31f25372c87782b10ed1860017e5.jpg',
#   'birthday': 'Jun 1',
#   'major': 'Computer Science & Economics',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '1',
#   'birth_month': '6',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 38245,
#   'upi': 24577575,
#   'netid': 'cw946',
#   'email': 'clara.wang@yale.edu',
#   'mailbox': 'clara.wang@bulldogs.yale.edu',
#   'first_name': 'Clara',
#   'last_name': 'Wang',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Comb Progs:Biol&Biomed Science',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2027,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54426,
#   'upi': 17110126,
#   'netid': 'wfm24',
#   'email': 'william.mcgahan@yale.edu',
#   'mailbox': 'william.mcgahan@bulldogs.yale.edu',
#   'first_name': 'Billy',
#   'last_name': 'McGahan',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '3190 Ridgewood Rd NW\nAtlanta, GA 30327-1936',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': {'address_components': [{'long_name': '3190',
#      'short_name': '3190',
#      'types': ['street_number']},
#     {'long_name': 'Ridgewood Road Northwest',
#      'short_name': 'Ridgewood Rd NW',
#      'types': ['route']},
#     {'long_name': 'Paces',
#      'short_name': 'Paces',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Atlanta',
#      'short_name': 'Atlanta',
#      'types': ['locality', 'political']},
#     {'long_name': 'Fulton County',
#      'short_name': 'Fulton County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Georgia',
#      'short_name': 'GA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '30327', 'short_name': '30327', 'types': ['postal_code']},
#     {'long_name': '1936',
#      'short_name': '1936',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '3190 Ridgewood Rd NW, Atlanta, GA 30327, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 33.8419748,
#       'lng': -84.4469969},
#      'southwest': {'lat': 33.8415547, 'lng': -84.4473221}},
#     'location': {'lat': 33.8417421, 'lng': -84.4471726},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 33.84311373029149,
#       'lng': -84.44581051970849},
#      'southwest': {'lat': 33.84041576970849, 'lng': -84.4485084802915}}},
#    'place_id': 'ChIJzU7Upq8a9YgRxxbAz4LNdg0',
#    'types': ['premise']},
#   'year': 2021,
#   'college': 'Davenport',
#   'college_code': 'DC',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/12ab5795d9102297a7428df87bce9352.jpg',
#   'birthday': 'Jan 9',
#   'major': 'Statistics and Data Science',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-84.4471726, 33.8417421]},
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26670,
#   'upi': 15096991,
#   'netid': 'im249',
#   'email': 'isabelle.margerit@yale.edu',
#   'mailbox': 'isabelle.margerit@bulldogs.yale.edu',
#   'first_name': 'Isabelle',
#   'last_name': 'Margerit',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': 'Nurse Midwifery',
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 11349,
#   'upi': 24292536,
#   'netid': 'zd78',
#   'email': 'zehao.dou@yale.edu',
#   'mailbox': 'zehao.dou@bulldogs.yale.edu',
#   'first_name': 'Zehao',
#   'last_name': 'Dou',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Statistics and Data Science',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Graduate School Student',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://statistics.yale.edu/people/zehao-dou',
#   'city': None,
#   'year': 2026,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 11350,
#   'upi': 24318070,
#   'netid': 'awd26',
#   'email': 'astri.doub@yale.edu',
#   'mailbox': 'astri.doub@bulldogs.yale.edu',
#   'first_name': 'Astri',
#   'last_name': 'Doub',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Owings Mills, MD 21117-2922',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://clais.macmillan.yale.edu/people/astri-doub',
#   'city': {'address_components': [{'long_name': 'Owings Mills',
#      'short_name': 'Owings Mills',
#      'types': ['locality', 'political']},
#     {'long_name': 'Baltimore County',
#      'short_name': 'Baltimore County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Maryland',
#      'short_name': 'MD',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Owings Mills, MD, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 39.447187, 'lng': -76.7612699},
#      'southwest': {'lat': 39.3824739, 'lng': -76.83135899999999}},
#     'location': {'lat': 39.4195499, 'lng': -76.7802528},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 39.447187, 'lng': -76.7612699},
#      'southwest': {'lat': 39.3824739, 'lng': -76.83135899999999}}},
#    'place_id': 'ChIJf4msIK0XyIkR9AmM6zFf69M',
#    'types': ['locality', 'political']},
#   'year': 2024,
#   'college': 'Jonathan Edwards',
#   'college_code': 'JE',
#   'leave': False,
#   'eli_whitney': False,
#   'image': None,
#   'birthday': 'Aug 17',
#   'major': 'Undeclared',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': {'type': 'Point', 'coordinates': [-76.7802528, 39.4195499]},
#   'birth_day': '17',
#   'birth_month': '8',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26694,
#   'upi': 24353022,
#   'netid': 'ttm25',
#   'email': 'tim.marian@yale.edu',
#   'mailbox': 'ttm25@connect.yale.edu',
#   'first_name': 'Tim',
#   'last_name': 'Marian',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26594,
#   'upi': 24085850,
#   'netid': 'cm2588',
#   'email': 'churong.mao@yale.edu',
#   'mailbox': 'churong.mao@bulldogs.yale.edu',
#   'first_name': 'Churong',
#   'last_name': 'Mao',
#   'school_code': 'AT',
#   'school': 'School of Art',
#   'curriculum': 'Graphic Design',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 40,
#   'upi': 17252586,
#   'netid': 'sja42',
#   'email': 'samuel.andersson@yale.edu',
#   'mailbox': 'samuel.andersson@bulldogs.yale.edu',
#   'first_name': 'Samuel',
#   'last_name': 'Andersson',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Linguistics',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://ling.yale.edu/people/samuel-andersson',
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': 'https://www.samuelandersson.net',
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 11399,
#   'upi': 17586415,
#   'netid': 'hnd5',
#   'email': 'hollie.dowd@yale.edu',
#   'mailbox': 'hnd5@connect.yale.edu',
#   'first_name': 'Hollie',
#   'last_name': 'Dowd',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 11405,
#   'upi': 17473858,
#   'netid': 'paf35',
#   'email': 'patty.dowley@yale.edu',
#   'mailbox': 'paf35@connect.yale.edu',
#   'first_name': 'Patty',
#   'last_name': 'Dowley',
#   'school_code': 'NR',
#   'school': 'School of Nursing',
#   'curriculum': 'Family Nurse Practitioner',
#   'organization_code': 'NUR',
#   'organization': 'School of Nursing',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_ba40e7913ee8a1e0cff8632164a3ab88.mp3',
#   'pronouns': 'She / her / hers',
#   'phonetic_name': 'Pa-trish-a Dow-lee',
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 11413,
#   'upi': 24594524,
#   'netid': 'jld238',
#   'email': 'jackson.downey@yale.edu',
#   'mailbox': 'jackson.downey@bulldogs.yale.edu',
#   'first_name': 'Jackson',
#   'last_name': 'Downey',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '4145 Stansbury Ave\nSherman Oaks, CA 91423-4621',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Benjamin Franklin',
#   'college_code': 'BF',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/011e503191b1fbf95bc52c73e6ddc7b9.jpg',
#   'birthday': 'Jul 2',
#   'major': 'Undeclared',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '2',
#   'birth_month': '7',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26611,
#   'upi': 24576419,
#   'netid': 'ttm26',
#   'email': 'tyler.mar@yale.edu',
#   'mailbox': 'ttm26@connect.yale.edu',
#   'first_name': 'Tyler',
#   'last_name': 'Mar',
#   'school_code': 'FS',
#   'school': 'School of the Environment',
#   'curriculum': 'MESc',
#   'organization_code': 'ENV',
#   'organization': 'School of the Environment',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26731,
#   'upi': 24587673,
#   'netid': 'tm888',
#   'email': 'tiana.marion@yale.edu',
#   'mailbox': 'tiana.marion@bulldogs.yale.edu',
#   'first_name': 'Tiana',
#   'last_name': 'Marion',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': 'Salina, KS 67401-7260',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Saybrook',
#   'college_code': 'SY',
#   'leave': False,
#   'eli_whitney': False,
#   'image': None,
#   'birthday': None,
#   'major': 'Undeclared',
#   'phone': '2034360951',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26767,
#   'upi': 15812130,
#   'netid': 'jhm65',
#   'email': 'justin.markowski@yale.edu',
#   'mailbox': 'jhm65@connect.yale.edu',
#   'first_name': 'Justin',
#   'last_name': 'Markowski',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Public Health',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26785,
#   'upi': 17524127,
#   'netid': 'sem99',
#   'email': 'stephen.marks@yale.edu',
#   'mailbox': 'sem99@connect.yale.edu',
#   'first_name': 'Stephen',
#   'last_name': 'Marks',
#   'school_code': 'DR',
#   'school': 'School of Drama',
#   'curriculum': 'School of Drama',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54563,
#   'upi': 24115039,
#   'netid': 'kjm79',
#   'email': 'kj.mcconnell@yale.edu',
#   'mailbox': 'kj.mcconnell@bulldogs.yale.edu',
#   'first_name': 'KJ',
#   'last_name': 'McConnell',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Ezra Stiles',
#   'college_code': 'ES',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/8d8e7f8f1c26199755414c9f79d2f6f0.jpg',
#   'birthday': None,
#   'major': 'Undeclared',
#   'phone': '2034360170',
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54539,
#   'upi': 17332197,
#   'netid': 'wpm9',
#   'email': 'patrick.mccormick@yale.edu',
#   'mailbox': 'wpm9@connect.yale.edu',
#   'first_name': 'Patrick',
#   'last_name': 'McCormick',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 54521,
#   'upi': 24120972,
#   'netid': 'hcm33',
#   'email': 'hunter.mccurdy@yale.edu',
#   'mailbox': 'hcm33@connect.yale.edu',
#   'first_name': 'Hunter',
#   'last_name': 'McCurdy',
#   'school_code': 'MD',
#   'school': 'School of Medicine',
#   'curriculum': 'Medicine',
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 26900,
#   'upi': 24072845,
#   'netid': 'ejm83',
#   'email': 'eleanor.martin@yale.edu',
#   'mailbox': 'eleanor.martin@bulldogs.yale.edu',
#   'first_name': 'Eleanor',
#   'last_name': 'Martin',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Classics',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 11529,
#   'upi': 24554625,
#   'netid': 'ad2497',
#   'email': 'alexander.duarte@yale.edu',
#   'mailbox': 'alexander.duarte@bulldogs.yale.edu',
#   'first_name': 'Alexander',
#   'last_name': 'Duarte',
#   'school_code': 'PH',
#   'school': 'School of Public Health',
#   'curriculum': 'School of Public Health',
#   'organization_code': 'SPH',
#   'organization': 'School of Public Health',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
# ...
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32236,
#   'upi': 24349078,
#   'netid': 'et479',
#   'email': 'eriele.tellis@yale.edu',
#   'mailbox': 'et479@connect.yale.edu',
#   'first_name': 'Eriele',
#   'last_name': 'Tellis',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': 'https://us-nc-recordings.s3.amazonaws.com/recording_1ad932c4f0e6f09c19e81962b3bcd223.mp3',
#   'pronouns': 'She/Her',
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32234,
#   'upi': 15776685,
#   'netid': 'jt735',
#   'email': 'justin.toh@yale.edu',
#   'mailbox': 'justin.toh@bulldogs.yale.edu',
#   'first_name': 'Justin',
#   'last_name': 'Toh',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Microbiology',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32226,
#   'upi': 15233688,
#   'netid': 'pt284',
#   'email': 'pamela.torola@yale.edu',
#   'mailbox': 'pamela.torola@bulldogs.yale.edu',
#   'first_name': 'Pamela',
#   'last_name': 'Torola',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Economics',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://economics.yale.edu/people/graduate-students/pamela-torola',
#   'city': None,
#   'year': 2027,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32394,
#   'upi': 24379695,
#   'netid': 'ku53',
#   'email': 'kristina.ulicna@yale.edu',
#   'mailbox': 'kristina.ulicna@bulldogs.yale.edu',
#   'first_name': 'Kristina',
#   'last_name': 'Ulicna',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Cell Biology',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2021,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 50738,
#   'upi': 15288513,
#   'netid': 'ceo27',
#   'email': 'christine.olson@yale.edu',
#   'mailbox': 'christine.olson@bulldogs.yale.edu',
#   'first_name': 'Christine',
#   'last_name': 'Olson',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'History of Art',
#   'organization_code': None,
#   'organization': None,
#   'title': 'Seventh Year',
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://arthistory.yale.edu/people/christine-olson',
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://arthistory.yale.edu/sites/default/files/styles/228x269/public/pictures/picture-141-1475609513.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3936,
#   'upi': 24570690,
#   'netid': 'rjb95',
#   'email': 'ryan.bibb@yale.edu',
#   'mailbox': 'ryan.bibb@bulldogs.yale.edu',
#   'first_name': 'Ryan',
#   'last_name': 'Bibb',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '1101 W Granger St\nBroken Arrow, OK 74012-0729',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Davenport',
#   'college_code': 'DC',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/bc110473fb4eed4077bfea6fba0457d8.jpg',
#   'birthday': 'Dec 5',
#   'major': 'Undeclared',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '5',
#   'birth_month': '12',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3947,
#   'upi': 24571761,
#   'netid': 'emb252',
#   'email': 'elizabeth.bickel@yale.edu',
#   'mailbox': 'elizabeth.bickel@bulldogs.yale.edu',
#   'first_name': 'Elizabeth',
#   'last_name': 'Bickel',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '6120 Auburndale Dr\nGreensboro, NC 27410-4902',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2025,
#   'college': 'Berkeley',
#   'college_code': 'BK',
#   'leave': False,
#   'eli_whitney': False,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/2f774a1e01dcce3e47c17a4f7051bfdc.jpg',
#   'birthday': 'Feb 1',
#   'major': 'Undeclared',
#   'phone': '2034360368',
#   'access_code': '6-0368',
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '1',
#   'birth_month': '2',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24648737,
#   'netid': 'eho8',
#   'email': 'elijah.olson@yale.edu',
#   'mailbox': 'eho8@connect.yale.edu',
#   'first_name': 'Elijah',
#   'last_name': 'Olson',
#   'school_code': 'LW',
#   'school': 'Law School',
#   'curriculum': 'Law School',
#   'organization_code': 'LAW',
#   'organization': 'Law School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 50745,
#   'upi': 24542300,
#   'netid': 'eo326',
#   'email': 'emma.olson@yale.edu',
#   'mailbox': 'emma.olson@bulldogs.yale.edu',
#   'first_name': 'Emma',
#   'last_name': 'Olson',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'Medieval Studies',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://medieval.yale.edu/people/emma-olson',
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': None,
#   'upi': 24628796,
#   'netid': 'hmo22',
#   'email': 'helen.olson@yale.edu',
#   'mailbox': 'helen.olson@bulldogs.yale.edu',
#   'first_name': 'Helen',
#   'last_name': 'Olson',
#   'school_code': 'YC',
#   'school': 'Yale College',
#   'curriculum': None,
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': '515 Country Ridge Cir\nBel Air, MD 21015-8533',
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2024,
#   'college': 'Berkeley',
#   'college_code': 'BK',
#   'leave': None,
#   'eli_whitney': True,
#   'image': 'https://yalestudentphotos.s3.amazonaws.com/c05c11c45476d27c80cfbe7558097aba.jpg',
#   'birthday': 'Aug 4',
#   'major': 'Archaeological Studies',
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': '4',
#   'birth_month': '8',
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32396,
#   'upi': 17054485,
#   'netid': 'mfu3',
#   'email': 'monique.ulysses@yale.edu',
#   'mailbox': 'monique.ulysses@bulldogs.yale.edu',
#   'first_name': 'Monique',
#   'last_name': 'Ulysses',
#   'school_code': 'GS',
#   'school': 'Graduate School of Arts & Sciences',
#   'curriculum': 'History',
#   'organization_code': None,
#   'organization': None,
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': 'https://history.yale.edu/people/monique-ulysses',
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': 'https://history.yale.edu/sites/default/files/styles/portrait/public/pictures/picture-628-1593716616.jpg',
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 32417,
#   'upi': 24089335,
#   'netid': 'lru2',
#   'email': 'lia.umlauf@yale.edu',
#   'mailbox': 'lia.umlauf@bulldogs.yale.edu',
#   'first_name': 'Lia',
#   'last_name': 'Umlauf',
#   'school_code': 'DI',
#   'school': 'Divinity School',
#   'curriculum': 'Religion & the Arts',
#   'organization_code': 'DIV',
#   'organization': 'Divinity School',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 27241,
#   'upi': 24121601,
#   'netid': 'jmo44',
#   'email': 'jamieson.omarr@yale.edu',
#   'mailbox': 'jmo44@connect.yale.edu',
#   'first_name': 'Jamieson',
#   'last_name': "O'Marr",
#   'school_code': 'MD',
#   'school': 'School of Medicine',
#   'curriculum': 'Medicine',
#   'organization_code': 'MED',
#   'organization': 'School of Medicine',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2023,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None},
#  {'id': 3960,
#   'upi': 24588523,
#   'netid': 'dmb268',
#   'email': 'deena.bielecki@yale.edu',
#   'mailbox': 'dmb268@connect.yale.edu',
#   'first_name': 'Deena',
#   'last_name': 'Bielecki',
#   'school_code': 'MG',
#   'school': 'School of Management',
#   'curriculum': 'School of Management',
#   'organization_code': 'SOM',
#   'organization': 'School of Management',
#   'title': None,
#   'address': None,
#   'unit_class': None,
#   'unit_code': None,
#   'unit': None,
#   'postal_address': None,
#   'office_building': None,
#   'cv': None,
#   'profile': None,
#   'city': None,
#   'year': 2022,
#   'college': None,
#   'college_code': None,
#   'leave': None,
#   'eli_whitney': None,
#   'image': None,
#   'birthday': None,
#   'major': None,
#   'phone': None,
#   'access_code': None,
#   'middle_name': None,
#   'office_room': None,
#   'website': None,
#   'education': None,
#   'name_recording': None,
#   'pronouns': None,
#   'phonetic_name': None,
#   'suffix': None,
#   'fax': None,
#   'city_as_point': None,
#   'birth_day': None,
#   'birth_month': None,
#   'visitor': None,
#   'preferred_name': None,
#   'place_id': None}]

# %%
# Out:
# import.meta.env.VITE_GOOGLE_MAP_KEY
